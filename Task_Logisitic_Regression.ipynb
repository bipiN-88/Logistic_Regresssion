# %% [markdown]
# # **Importing the libraries**

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # **Importing the Dataset**

# %%
df = pd.read_csv('Algerian_forest_fires_dataset_UPDATE.csv', skiprows=1)
df.head()
# Out:
#   day month  year Temperature  RH  Ws Rain   FFMC  DMC    DC  ISI  BUI  FWI  \
# 0  01    06  2012          29  57  18     0  65.7  3.4   7.6  1.3  3.4  0.5
# 1  02    06  2012          29  61  13   1.3  64.4  4.1   7.6    1  3.9  0.4
# 2  03    06  2012          26  82  22  13.1  47.1  2.5   7.1  0.3  2.7  0.1
# 3  04    06  2012          25  89  13   2.5  28.6  1.3   6.9    0  1.7    0
# 4  05    06  2012          27  77  16     0  64.8    3  14.2  1.2  3.9  0.5
#
#      Classes
# 0  not fire
# 1  not fire
# 2  not fire
# 3  not fire
# 4  not fire

# %% [markdown]
# # **Viewing the dataframe**

# %% [markdown]
# **a) Creating a copy of the dataframe**

# %%
df_1 = df.copy()

# %% [markdown]
# **the first five rows of the dataframe**

# %%
df_1.head()
# Out:
#   day month  year Temperature  RH  Ws Rain   FFMC  DMC    DC  ISI  BUI  FWI  \
# 0  01    06  2012          29  57  18     0  65.7  3.4   7.6  1.3  3.4  0.5
# 1  02    06  2012          29  61  13   1.3  64.4  4.1   7.6    1  3.9  0.4
# 2  03    06  2012          26  82  22  13.1  47.1  2.5   7.1  0.3  2.7  0.1
# 3  04    06  2012          25  89  13   2.5  28.6  1.3   6.9    0  1.7    0
# 4  05    06  2012          27  77  16     0  64.8    3  14.2  1.2  3.9  0.5
#
#      Classes
# 0  not fire
# 1  not fire
# 2  not fire
# 3  not fire
# 4  not fire

# %%
df_1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 246 entries, 0 to 245
# Data columns (total 14 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   day          246 non-null    object
#  1   month        245 non-null    object
#  2   year         245 non-null    object
#  3   Temperature  245 non-null    object
#  4    RH          245 non-null    object
#  5    Ws          245 non-null    object
#  6   Rain         245 non-null    object
#  7   FFMC         245 non-null    object
#  8   DMC          245 non-null    object
#  9   DC           245 non-null    object
#  10  ISI          245 non-null    object
#  11  BUI          245 non-null    object
#  12  FWI          245 non-null    object
#  13  Classes      244 non-null    object
# dtypes: object(14)
# memory usage: 27.0+ KB

# %%
df_1.describe()
# Out:
#         day month  year Temperature   RH   Ws Rain   FFMC  DMC   DC  ISI  BUI  \
# count   246   245   245         245  245  245   245   245  245  245  245  245
# unique   33     5     2          20   63   19    40   174  167  199  107  175
# top      01    07  2012          35   64   14     0  88.9  7.9    8  1.1    3
# freq      8    62   244          29   10   43   133     8    5    5    8    5
#
#         FWI Classes
# count   245       244
# unique  128         9
# top     0.4   fire
# freq     12       131

# %%
df_1.columns
# Out:
# Index(['day', 'month', 'year', 'Temperature', ' RH', ' Ws', 'Rain ', 'FFMC',
#        'DMC', 'DC', 'ISI', 'BUI', 'FWI', 'Classes  '],
#       dtype='object')

# %%
df_1[df_1.isna().any(axis=1)]
# Out:
#                                day month  year Temperature   RH   Ws Rain   \
# 122  Sidi-Bel Abbes Region Dataset   NaN   NaN         NaN  NaN  NaN   NaN
# 167                             14    07  2012          37   37   18   0.2
#
#      FFMC   DMC      DC   ISI   BUI      FWI Classes
# 122   NaN   NaN     NaN   NaN   NaN      NaN       NaN
# 167  88.9  12.9  14.6 9  12.5  10.4  fire          NaN

# %%
df_1.loc[160:170]
# Out:
#     day month  year Temperature  RH  Ws Rain   FFMC   DMC      DC   ISI   BUI  \
# 160  07    07  2012          38  43  13   0.5    85    13    35.4   4.1  13.7
# 161  08    07  2012          35  47  18     6  80.8   9.8     9.7   3.1   9.4
# 162  09    07  2012          36  43  15   1.9  82.3   9.4     9.9   3.2     9
# 163  10    07  2012          34  51  16   3.8  77.5     8     9.5     2   7.7
# 164  11    07  2012          34  56  15   2.9  74.8   7.1     9.5   1.6   6.8
# 165  12    07  2012          36  44  13     0  90.1  12.6    19.4   8.3  12.5
# 166  13    07  2012          39  45  13   0.6  85.2  11.3    10.4   4.2  10.9
# 167  14    07  2012          37  37  18   0.2  88.9  12.9  14.6 9  12.5  10.4
# 168  15    07  2012          34  45  17     0  90.5    18    24.1  10.9  17.7
# 169  16    07  2012          31  83  17     0  84.5  19.4    33.1   4.7  19.2
# 170  17    07  2012          32  81  17     0  84.6  21.1    42.3   4.7  20.9
#
#          FWI    Classes
# ...

# %%
df_1[df_1['FWI']=='fire']
# Out:
# Empty DataFrame
# Columns: [day, month, year, Temperature,  RH,  Ws, Rain , FFMC, DMC, DC, ISI, BUI, FWI, Classes  ]
# Index: []

# %%
print(df_1.apply(lambda col: col.unique()))
# Out:
# day            [01, 02, 03, 04, 05, 06, 07, 08, 09, 10, 11, 1...
# month                               [06, 07, 08, 09, nan, month]
# year                                           [2012, nan, year]
# Temperature    [29, 26, 25, 27, 31, 33, 30, 28, 32, 34, 35, 3...
#  RH            [57, 61, 82, 89, 77, 67, 54, 73, 88, 79, 65, 8...
#  Ws            [18, 13, 22, 16, 14, 15, 12, 19, 21, 20, 17, 2...
# Rain           [0, 1.3, 13.1, 2.5, 0.2, 1.2, 0.5, 3.1, 0.7, 0...
# FFMC           [65.7, 64.4, 47.1, 28.6, 64.8, 82.6, 88.2, 86....
# DMC            [3.4, 4.1, 2.5, 1.3, 3, 5.8, 9.9, 12.1, 7.9, 9...
# DC             [7.6, 7.1, 6.9, 14.2, 22.2, 30.5, 38.3, 38.8, ...
# ISI            [1.3, 1, 0.3, 0, 1.2, 3.1, 6.4, 5.6, 0.4, 4, 4...
# BUI            [3.4, 3.9, 2.7, 1.7, 7, 10.9, 13.5, 10.5, 12.6...
# FWI            [0.5, 0.4, 0.1, 0, 2.5, 7.2, 7.1, 0.3, 0.9, 5....
# Classes        [not fire   , fire   , fire, fire , not fire, ...
# dtype: object

# %% [markdown]
# # **Preparing the dataframe**

# %%
df_1.drop([122,123,124], inplace = True)

# %%
df_1.loc[:122, 'Region'] = 1
df_1.loc[125:, 'Region'] = 0

# %%
df_1.loc[120:130]
# Out:
#     day month  year Temperature  RH  Ws Rain   FFMC  DMC    DC  ISI   BUI  \
# 120  29    09  2012          26  80  16   1.8  47.4  2.9   7.7  0.3     3
# 121  30    09  2012          25  78  14   1.4    45  1.9   7.5  0.2   2.4
# 125  02    06  2012          30  73  13     4  55.7  2.7   7.8  0.6   2.9
# 126  03    06  2012          29  80  14     2  48.7  2.2   7.6  0.3   2.6
# 127  04    06  2012          30  64  14     0  79.4  5.2  15.4  2.2   5.6
# 128  05    06  2012          32  60  14   0.2  77.1    6  17.6  1.8   6.5
# 129  06    06  2012          35  54  11   0.1  83.7  8.4  26.3  3.1   9.3
# 130  07    06  2012          35  44  17   0.2  85.6  9.9  28.9  5.4  10.7
#
#      FWI    Classes    Region
# 120  0.1  not fire        1.0
# 121  0.1  not fire        1.0
# 125  0.2  not fire        0.0
# 126  0.1  not fire        0.0
# 127    1  not fire        0.0
# 128  0.9  not fire        0.0
# 129  3.1      fire        0.0
# 130    6      fire        0.0

# %%
df_1.columns = df_1.columns.str.strip()
df_1.columns
# Out:
# Index(['day', 'month', 'year', 'Temperature', 'RH', 'Ws', 'Rain', 'FFMC',
#        'DMC', 'DC', 'ISI', 'BUI', 'FWI', 'Classes', 'Region'],
#       dtype='object')

# %%
df_1.columns
# Out:
# Index(['day', 'month', 'year', 'Temperature', 'RH', 'Ws', 'Rain', 'FFMC',
#        'DMC', 'DC', 'ISI', 'BUI', 'FWI', 'Classes', 'Region'],
#       dtype='object')

# %%
df_1.loc[167, 'Classes']
# Out:
# nan

# %%
temp = df_1.loc[167, 'FWI']
df_1.loc[167, 'FWI'] = df_1.loc[167, 'Classes']
df_1.loc[167, 'Classes'] = temp
df_1.loc[167]
# Out:
# day                 14
# month               07
# year              2012
# Temperature         37
# RH                  37
# Ws                  18
# Rain               0.2
# FFMC              88.9
# DMC               12.9
# DC              14.6 9
# ISI               12.5
# BUI               10.4
# FWI                NaN
# Classes        fire
# Region             0.0
# Name: 167, dtype: object

# %%
df_1['Classes'].unique()
# Out:
# array(['not fire   ', 'fire   ', 'fire', 'fire ', 'not fire', 'not fire ',
#        'not fire     ', 'not fire    '], dtype=object)

# %%
df_1['Classes']= df_1['Classes'].str.strip()
df_1['Classes'].unique()
# Out:
# array(['not fire', 'fire'], dtype=object)

# %%
df_1.loc[167,'FWI']
# Out:
# nan

# %% [markdown]
# # **Filling Missing Values**

# %%
df_1[df_1.isna().any(axis=1)]
# Out:
#     day month  year Temperature  RH  Ws Rain  FFMC   DMC      DC   ISI   BUI  \
# 167  14    07  2012          37  37  18  0.2  88.9  12.9  14.6 9  12.5  10.4
#
#      FWI Classes  Region
# 167  NaN    fire     0.0

# %%
from sklearn.impute import SimpleImputer
imputer = SimpleImputer(missing_values=np.nan, strategy='mean')
imputer.fit(df_1[['FWI']])
df_1[['FWI']]=imputer.transform(df_1[['FWI']])

# %%
df_1.isna().sum()
# Out:
# day            0
# month          0
# year           0
# Temperature    0
# RH             0
# Ws             0
# Rain           0
# FFMC           0
# DMC            0
# DC             0
# ISI            0
# BUI            0
# FWI            0
# Classes        0
# Region         0
# dtype: int64

# %% [markdown]
# **Converting the dataset features datatype**

# %%
num = ['day','month','year','Temperature', 'RH', 'Ws', 'Rain', 'FFMC', 'DMC', 'DC', 'ISI', 'BUI',
       'FWI']

# %%
df_1['day']         = df_1['day'].astype('float')
df_1['month']       = df_1['month'].astype('float')
df_1['year']        = df_1['year'].astype('float')
df_1['Temperature'] = df_1['Temperature'].astype('float')
df_1['RH']          = df_1['RH'].astype('float')
df_1['Ws']          = df_1['Ws'].astype('float')
df_1['Rain']        = df_1['Rain'].astype('float')
df_1['FFMC']        = df_1['FFMC'].astype('float')
df_1['DMC']         = df_1['DMC'].astype('float')

df_1['ISI']         = df_1['ISI'].astype('float')
df_1['BUI']         = df_1['BUI'].astype('float')
df_1['FWI']         = df_1['FWI'].astype('float')

# %%
df_1['DC']  = df_1['DC'].str.replace(" ","")
df_1['DC']  = df_1['DC'].astype('float')

# %%
df_1.dtypes
# Out:
# day            float64
# month          float64
# year           float64
# Temperature    float64
# RH             float64
# Ws             float64
# Rain           float64
# FFMC           float64
# DMC            float64
# DC             float64
# ISI            float64
# BUI            float64
# FWI            float64
# Classes         object
# Region         float64
# dtype: object

# %% [markdown]
# # **Splitting the dataset**

# %%
df_1.head()
# Out:
#    day  month    year  Temperature    RH    Ws  Rain  FFMC  DMC    DC  ISI  \
# 0  1.0    6.0  2012.0         29.0  57.0  18.0   0.0  65.7  3.4   7.6  1.3
# 1  2.0    6.0  2012.0         29.0  61.0  13.0   1.3  64.4  4.1   7.6  1.0
# 2  3.0    6.0  2012.0         26.0  82.0  22.0  13.1  47.1  2.5   7.1  0.3
# 3  4.0    6.0  2012.0         25.0  89.0  13.0   2.5  28.6  1.3   6.9  0.0
# 4  5.0    6.0  2012.0         27.0  77.0  16.0   0.0  64.8  3.0  14.2  1.2
#
#    BUI  FWI   Classes  Region
# 0  3.4  0.5  not fire     1.0
# 1  3.9  0.4  not fire     1.0
# 2  2.7  0.1  not fire     1.0
# 3  1.7  0.0  not fire     1.0
# 4  3.9  0.5  not fire     1.0

# %%
y = df_1.loc[:,'Classes']

# %%
y.shape
# Out:
# (243,)

# %%
X_col=[name for name in df_1.columns if name not in ['Classes']]
X = df_1.loc[:, X_col]
X.head()
# Out:
#    day  month    year  Temperature    RH    Ws  Rain  FFMC  DMC    DC  ISI  \
# 0  1.0    6.0  2012.0         29.0  57.0  18.0   0.0  65.7  3.4   7.6  1.3
# 1  2.0    6.0  2012.0         29.0  61.0  13.0   1.3  64.4  4.1   7.6  1.0
# 2  3.0    6.0  2012.0         26.0  82.0  22.0  13.1  47.1  2.5   7.1  0.3
# 3  4.0    6.0  2012.0         25.0  89.0  13.0   2.5  28.6  1.3   6.9  0.0
# 4  5.0    6.0  2012.0         27.0  77.0  16.0   0.0  64.8  3.0  14.2  1.2
#
#    BUI  FWI  Region
# 0  3.4  0.5     1.0
# 1  3.9  0.4     1.0
# 2  2.7  0.1     1.0
# 3  1.7  0.0     1.0
# 4  3.9  0.5     1.0

# %%
X.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 243 entries, 0 to 245
# Data columns (total 14 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   day          243 non-null    float64
#  1   month        243 non-null    float64
#  2   year         243 non-null    float64
#  3   Temperature  243 non-null    float64
#  4   RH           243 non-null    float64
#  5   Ws           243 non-null    float64
#  6   Rain         243 non-null    float64
#  7   FFMC         243 non-null    float64
#  8   DMC          243 non-null    float64
#  9   DC           243 non-null    float64
#  10  ISI          243 non-null    float64
#  11  BUI          243 non-null    float64
#  12  FWI          243 non-null    float64
#  13  Region       243 non-null    float64
# dtypes: float64(14)
# memory usage: 36.6 KB

# %% [markdown]
# # **Checking with OLS(Ordinary least square as well)**

# %%
y.unique()
# Out:
# array(['not fire', 'fire'], dtype=object)

# %%
y_ols = y.map({'not fire':0, 'fire':1})

# %%
import statsmodels.api as sm
X_ols_input = sm.add_constant(X)
model = sm.OLS(y_ols, X_ols_input).fit()
# Out:
# /usr/local/lib/python3.7/dist-packages/statsmodels/tsa/tsatools.py:142: FutureWarning: In a future version of pandas all arguments of concat except for the argument 'objs' will be keyword-only
#   x = pd.concat(x[::order], 1)

# %%
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                Classes   R-squared:                       0.714
# Model:                            OLS   Adj. R-squared:                  0.697
# Method:                 Least Squares   F-statistic:                     43.89
# Date:                Sat, 29 Oct 2022   Prob (F-statistic):           9.11e-55
# Time:                        08:50:16   Log-Likelihood:                -22.193
# No. Observations:                 243   AIC:                             72.39
# Df Residuals:                     229   BIC:                             121.3
# Df Model:                          13
# Covariance Type:            nonrobust
# ...
#                   coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------
# day            -0.0012      0.002     -0.503      0.616      -0.006       0.004
# ...

# %%
X_ols_input.iloc[:,1:].corr()
# Out:
#                 month  year  Temperature        RH        Ws      Rain  \
# month        1.000000   NaN    -0.059505 -0.034650 -0.048731  0.035286
# year              NaN   NaN          NaN       NaN       NaN       NaN
# Temperature -0.059505   NaN     1.000000 -0.654829 -0.279276 -0.326794
# RH          -0.034650   NaN    -0.654829  1.000000  0.240177  0.223216
# Ws          -0.048731   NaN    -0.279276  0.240177  1.000000  0.170562
# Rain         0.035286   NaN    -0.326794  0.223216  0.170562  1.000000
# FFMC         0.007563   NaN     0.680171 -0.645312 -0.172025 -0.546607
# DMC          0.063059   NaN     0.483884 -0.403774 -0.006351 -0.289251
# DC           0.123518   NaN     0.370915 -0.218678  0.072150 -0.297374
# ISI          0.056441   NaN     0.608617 -0.690076  0.010151 -0.347950
# BUI          0.080848   NaN     0.456214 -0.347081  0.024856 -0.299885
# FWI          0.077899   NaN     0.565434 -0.576739  0.027723 -0.325059
# ...

# %% [markdown]
# # **Observation.**
#
# 1. There high correlation of BUI and ISI with FWI '
# 2. and P>|t| value for BUI is quite high 0.243.
# 3. So we are dropping BUI. and then check with OLS again

# %%
X = X.drop(labels = "BUI", axis = 1)

# %%
import statsmodels.api as sm
X_ols_input_1 = sm.add_constant(X)
model = sm.OLS(y_ols, X_ols_input_1).fit()
# Out:
# /usr/local/lib/python3.7/dist-packages/statsmodels/tsa/tsatools.py:142: FutureWarning: In a future version of pandas all arguments of concat except for the argument 'objs' will be keyword-only
#   x = pd.concat(x[::order], 1)

# %%
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                Classes   R-squared:                       0.712
# Model:                            OLS   Adj. R-squared:                  0.697
# Method:                 Least Squares   F-statistic:                     47.35
# Date:                Sat, 29 Oct 2022   Prob (F-statistic):           2.52e-55
# Time:                        08:50:16   Log-Likelihood:                -22.917
# No. Observations:                 243   AIC:                             71.83
# Df Residuals:                     230   BIC:                             117.2
# Df Model:                          12
# Covariance Type:            nonrobust
# ...
#                   coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------
# day            -0.0012      0.002     -0.491      0.624      -0.006       0.004
# ...

# %%
X_ols_input_1.iloc[:,1:].corr()
# Out:
#                 month  year  Temperature        RH        Ws      Rain  \
# month        1.000000   NaN    -0.059505 -0.034650 -0.048731  0.035286
# year              NaN   NaN          NaN       NaN       NaN       NaN
# Temperature -0.059505   NaN     1.000000 -0.654829 -0.279276 -0.326794
# RH          -0.034650   NaN    -0.654829  1.000000  0.240177  0.223216
# Ws          -0.048731   NaN    -0.279276  0.240177  1.000000  0.170562
# Rain         0.035286   NaN    -0.326794  0.223216  0.170562  1.000000
# FFMC         0.007563   NaN     0.680171 -0.645312 -0.172025 -0.546607
# DMC          0.063059   NaN     0.483884 -0.403774 -0.006351 -0.289251
# DC           0.123518   NaN     0.370915 -0.218678  0.072150 -0.297374
# ISI          0.056441   NaN     0.608617 -0.690076  0.010151 -0.347950
# FWI          0.077899   NaN     0.565434 -0.576739  0.027723 -0.325059
# Region      -0.005590   NaN    -0.274258  0.410093  0.172597  0.041040
#
# ...

# %% [markdown]
# # **Observation.**
#
# 1. There high correlation of DMC and ISI with FWI '
# 2. and P>|t| value for ISI is quite high 0.133.
# 3. So we are dropping ISI. and then check with OLS again

# %%
X = X.drop(labels = "ISI", axis = 1)

# %%
X_ols_input_2 = sm.add_constant(X)
model = sm.OLS(y_ols, X_ols_input_2).fit()
model.summary()
# Out:
# /usr/local/lib/python3.7/dist-packages/statsmodels/tsa/tsatools.py:142: FutureWarning: In a future version of pandas all arguments of concat except for the argument 'objs' will be keyword-only
#   x = pd.concat(x[::order], 1)
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                Classes   R-squared:                       0.709
# Model:                            OLS   Adj. R-squared:                  0.695
# Method:                 Least Squares   F-statistic:                     51.17
# Date:                Sat, 29 Oct 2022   Prob (F-statistic):           1.04e-55
# Time:                        08:50:16   Log-Likelihood:                -24.111
# No. Observations:                 243   AIC:                             72.22
# Df Residuals:                     231   BIC:                             114.1
# Df Model:                          11
# Covariance Type:            nonrobust
# ...

# %%
X_ols_input_2.iloc[:,1:].corr()
# Out:
#                 month  year  Temperature        RH        Ws      Rain  \
# month        1.000000   NaN    -0.059505 -0.034650 -0.048731  0.035286
# year              NaN   NaN          NaN       NaN       NaN       NaN
# Temperature -0.059505   NaN     1.000000 -0.654829 -0.279276 -0.326794
# RH          -0.034650   NaN    -0.654829  1.000000  0.240177  0.223216
# Ws          -0.048731   NaN    -0.279276  0.240177  1.000000  0.170562
# Rain         0.035286   NaN    -0.326794  0.223216  0.170562  1.000000
# FFMC         0.007563   NaN     0.680171 -0.645312 -0.172025 -0.546607
# DMC          0.063059   NaN     0.483884 -0.403774 -0.006351 -0.289251
# DC           0.123518   NaN     0.370915 -0.218678  0.072150 -0.297374
# FWI          0.077899   NaN     0.565434 -0.576739  0.027723 -0.325059
# Region      -0.005590   NaN    -0.274258  0.410093  0.172597  0.041040
#
#                  FFMC       DMC        DC       FWI    Region
# ...

# %% [markdown]
# # **Observations**
#
# 1. There high correlation of DMC and DC.
# 2. and P>|t| value for DC is quite high 0.315.
# 3. So we are dropping DC and then check with OLS again

# %%
X = X.drop(labels = "DC", axis = 1)

# %%
X_ols_input_3= sm.add_constant(X)
model = sm.OLS(y_ols, X_ols_input_3).fit()
model.summary()
# Out:
# /usr/local/lib/python3.7/dist-packages/statsmodels/tsa/tsatools.py:142: FutureWarning: In a future version of pandas all arguments of concat except for the argument 'objs' will be keyword-only
#   x = pd.concat(x[::order], 1)
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                Classes   R-squared:                       0.708
# Model:                            OLS   Adj. R-squared:                  0.695
# Method:                 Least Squares   F-statistic:                     56.18
# Date:                Sat, 29 Oct 2022   Prob (F-statistic):           2.23e-56
# Time:                        08:50:16   Log-Likelihood:                -24.643
# No. Observations:                 243   AIC:                             71.29
# Df Residuals:                     232   BIC:                             109.7
# Df Model:                          10
# Covariance Type:            nonrobust
# ...

# %%
X_ols_input_3.iloc[:,1:].corr()
# Out:
#                 month  year  Temperature        RH        Ws      Rain  \
# month        1.000000   NaN    -0.059505 -0.034650 -0.048731  0.035286
# year              NaN   NaN          NaN       NaN       NaN       NaN
# Temperature -0.059505   NaN     1.000000 -0.654829 -0.279276 -0.326794
# RH          -0.034650   NaN    -0.654829  1.000000  0.240177  0.223216
# Ws          -0.048731   NaN    -0.279276  0.240177  1.000000  0.170562
# Rain         0.035286   NaN    -0.326794  0.223216  0.170562  1.000000
# FFMC         0.007563   NaN     0.680171 -0.645312 -0.172025 -0.546607
# DMC          0.063059   NaN     0.483884 -0.403774 -0.006351 -0.289251
# FWI          0.077899   NaN     0.565434 -0.576739  0.027723 -0.325059
# Region      -0.005590   NaN    -0.274258  0.410093  0.172597  0.041040
#
#                  FFMC       DMC       FWI    Region
# month        0.007563  0.063059  0.077899 -0.005590
# year              NaN       NaN       NaN       NaN
# ...

# %% [markdown]
# 2. and P>|t| value for DC is quite high 0.133.

# %% [markdown]
# # **Observations**
#
# 1. Year has no correlation with any feature of the dataset
# 2. So we are dropping year

# %%
X = X.drop(labels = "year", axis = 1)

# %% [markdown]
# # **Splitting X and Y into training and test dataset.**

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X,y, test_size=0.25, random_state=42)

# %% [markdown]
# # **Applying logistic regression algorithm for model building on training dataset and **

# %%
from sklearn.linear_model import LogisticRegression
logisticRegr = LogisticRegression(max_iter = 1000)
logisticRegr.fit(X_train, y_train)
# Out:
# LogisticRegression(max_iter=1000)

# %%
y_pred = logisticRegr.predict(X_test)

# %%
score = logisticRegr.score(X_test, y_test)
print(score)
# Out:
# 0.9672131147540983

# %% [markdown]
# # **Calculating the scoring matrix on the model.**

# %%
from sklearn.metrics import confusion_matrix,f1_score,precision_score,recall_score,accuracy_score
cm_log_reg = confusion_matrix(y_test, y_pred)


ax = plt.subplot()


sns.heatmap(cm_log_reg, annot=True, ax = ax, fmt = '', cmap = 'coolwarm'); #annot=True to annotate cells

# labels, title and ticks
ax.set_xlabel('Predicted labels');
ax.set_ylabel('True labels'); 
ax.set_title('Confusion Matrix'); 
ax.xaxis.set_ticklabels(['Fire Yes', 'Fire No']); ax.yaxis.set_ticklabels(['Fire Yes', 'Fire No']);

# %%
from sklearn.metrics import classification_report
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#         fire       0.97      0.97      0.97        39
#     not fire       0.95      0.95      0.95        22
#
#     accuracy                           0.97        61
#    macro avg       0.96      0.96      0.96        61
# weighted avg       0.97      0.97      0.97        61
